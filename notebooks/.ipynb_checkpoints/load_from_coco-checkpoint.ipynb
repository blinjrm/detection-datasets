# %%
from detection_dataset import Convert

# %%
path = '/Users/jeromeblin/self/blinjrm/detection-dataset/data/raw'
splits = {
    'train': ('train.json', 'train'),
    'test': ('test.json', 'test'),
}

# %%
converter = Convert.from_coco(path=path, splits=splits)

# %%
converter

# %%
converter.dataset.data
# Out:
#         image_id  category_id                            attribute_ids  \
# 0          16305           32                                    [218]
# 1          16305           31                          [204, 205, 159]
# 2          16305           31                               [205, 159]
# 3          16305           22                                       []
# 4          16305           22                                       []
# ...          ...          ...                                      ...
# 342177     13599            8  [316, 317, 142, 295, 67, 127, 154, 115]
# 342178     13599           23                                       []
# 342179     13599           23                                       []
# 342180     13599           31                               [160, 204]
# 342181     13599           31                               [160, 204]
#
#                                                      bbox   area  bbox_id  \
# 0       <detection_dataset.bbox.Bbox object at 0x13eb6...   3052        0
# 1       <detection_dataset.bbox.Bbox object at 0x107c8...  12906        1
# 2       <detection_dataset.bbox.Bbox object at 0x13eb6...   5794        2
# 3       <detection_dataset.bbox.Bbox object at 0x107c5...   3838        3
# 4       <detection_dataset.bbox.Bbox object at 0x13eb6...   9415        4
# ...                                                   ...    ...      ...
# 342177  <detection_dataset.bbox.Bbox object at 0x1391e...  62602     9313
# 342178  <detection_dataset.bbox.Bbox object at 0x1391e...   1531     9314
# 342179  <detection_dataset.bbox.Bbox object at 0x1391e...    248     9315
# 342180  <detection_dataset.bbox.Bbox object at 0x1391e...  10809     9316
# 342181  <detection_dataset.bbox.Bbox object at 0x1391e...  11092     9317
#
#         width  height                            image_name  \
# 0         680    1024  2f10b4d61e445fe5d0777723630a2905.jpg
# 1         680    1024  2f10b4d61e445fe5d0777723630a2905.jpg
# 2         680    1024  2f10b4d61e445fe5d0777723630a2905.jpg
# 3         680    1024  2f10b4d61e445fe5d0777723630a2905.jpg
# 4         680    1024  2f10b4d61e445fe5d0777723630a2905.jpg
# ...       ...     ...                                   ...
# 342177    904    1024  d456b51deebc83e01cfef985d05e063e.jpg
# 342178    904    1024  d456b51deebc83e01cfef985d05e063e.jpg
# 342179    904    1024  d456b51deebc83e01cfef985d05e063e.jpg
# 342180    904    1024  d456b51deebc83e01cfef985d05e063e.jpg
# 342181    904    1024  d456b51deebc83e01cfef985d05e063e.jpg
#
#                                                image_path  split
# 0       /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 1       /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 2       /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 3       /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 4       /Users/jeromeblin/self/blinjrm/detection-datas...  train
# ...                                                   ...    ...
# 342177  /Users/jeromeblin/self/blinjrm/detection-datas...   test
# 342178  /Users/jeromeblin/self/blinjrm/detection-datas...   test
# 342179  /Users/jeromeblin/self/blinjrm/detection-datas...   test
# 342180  /Users/jeromeblin/self/blinjrm/detection-datas...   test
# 342181  /Users/jeromeblin/self/blinjrm/detection-datas...   test
#
# [342182 rows x 11 columns]

# %%
converter.dataset.categories
# Out:
# ['shirt, blouse',
#  'top, t-shirt, sweatshirt',
#  'sweater',
#  'cardigan',
#  'jacket',
#  'vest',
#  'pants',
#  'shorts',
#  'skirt',
#  'coat',
#  'dress',
#  'jumpsuit',
#  'cape',
#  'glasses',
#  'hat',
#  'headband, head covering, hair accessory',
#  'tie',
#  'glove',
#  'watch',
#  'belt',
#  'leg warmer',
#  'tights, stockings',
#  'sock',
#  'shoe',
#  'bag, wallet',
#  'scarf',
#  'umbrella',
#  'hood',
#  'collar',
#  'lapel',
#  'epaulette',
#  'sleeve',
#  'pocket',
#  'neckline',
#  'buckle',
#  'zipper',
#  'applique',
#  'bead',
#  'bow',
#  'flower',
#  'fringe',
#  'ribbon',
#  'rivet',
#  'ruffle',
#  'sequin',
#  'tassel']
