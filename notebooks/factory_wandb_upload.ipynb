# %%
from detection_dataset import Converter

# %%
read_config = {
    'dataset_format': 'coco',
    'path': '/Users/jeromeblin/self/blinjrm/detection-dataset/data/raw',
    'splits': {
        'train': ('train.json', 'train'),
        'test': ('test.json', 'test'),
    },
    'other': 'argument',
}

converter = Converter()
converter.read(**read_config)
converter.dataset.data.head(1)
# Out:
#                  category_id category  supercategory  \
# image_id bbox_id
# 16305    0                32   pocket  garment parts
#
#                                                                bbox width  \
# image_id bbox_id
# 16305    0        <detection_dataset.bbox.Bbox object at 0x1261b...   680
#
#                  height  area                            image_name  \
# image_id bbox_id
# 16305    0         1024  3052  2f10b4d61e445fe5d0777723630a2905.jpg
#
#                                                          image_path  split
# image_id bbox_id
# 16305    0        /Users/jeromeblin/self/blinjrm/detection-datas...  train

# %%
converter.dataset.data
# Out:
#                  category_id category  supercategory  \
# image_id bbox_id
# 16305    0                32   pocket  garment parts
#          1                31   sleeve  garment parts
#          2                31   sleeve  garment parts
#          3                22     sock  legs and feet
#          4                22     sock  legs and feet
# ...                      ...      ...            ...
# 13599    9313              8    skirt      lowerbody
#          9314             23     shoe  legs and feet
#          9315             23     shoe  legs and feet
#          9316             31   sleeve  garment parts
#          9317             31   sleeve  garment parts
#
#                                                                bbox width  \
# image_id bbox_id
# 16305    0        <detection_dataset.bbox.Bbox object at 0x1261b...   680
#          1        <detection_dataset.bbox.Bbox object at 0x1261b...   680
#          2        <detection_dataset.bbox.Bbox object at 0x1261b...   680
#          3        <detection_dataset.bbox.Bbox object at 0x1261b...   680
#          4        <detection_dataset.bbox.Bbox object at 0x16d85...   680
# ...                                                             ...   ...
# 13599    9313     <detection_dataset.bbox.Bbox object at 0x14b53...   904
#          9314     <detection_dataset.bbox.Bbox object at 0x14b53...   904
#          9315     <detection_dataset.bbox.Bbox object at 0x14b53...   904
#          9316     <detection_dataset.bbox.Bbox object at 0x14b53...   904
#          9317     <detection_dataset.bbox.Bbox object at 0x14b53...   904
#
#                  height   area                            image_name  \
# image_id bbox_id
# 16305    0         1024   3052  2f10b4d61e445fe5d0777723630a2905.jpg
#          1         1024  12906  2f10b4d61e445fe5d0777723630a2905.jpg
#          2         1024   5794  2f10b4d61e445fe5d0777723630a2905.jpg
#          3         1024   3838  2f10b4d61e445fe5d0777723630a2905.jpg
#          4         1024   9415  2f10b4d61e445fe5d0777723630a2905.jpg
# ...                 ...    ...                                   ...
# 13599    9313      1024  62602  d456b51deebc83e01cfef985d05e063e.jpg
#          9314      1024   1531  d456b51deebc83e01cfef985d05e063e.jpg
#          9315      1024    248  d456b51deebc83e01cfef985d05e063e.jpg
#          9316      1024  10809  d456b51deebc83e01cfef985d05e063e.jpg
#          9317      1024  11092  d456b51deebc83e01cfef985d05e063e.jpg
#
#                                                          image_path  split
# image_id bbox_id
# 16305    0        /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          1        /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          2        /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          3        /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          4        /Users/jeromeblin/self/blinjrm/detection-datas...  train
# ...                                                             ...    ...
# 13599    9313     /Users/jeromeblin/self/blinjrm/detection-datas...   test
#          9314     /Users/jeromeblin/self/blinjrm/detection-datas...   test
#          9315     /Users/jeromeblin/self/blinjrm/detection-datas...   test
#          9316     /Users/jeromeblin/self/blinjrm/detection-datas...   test
#          9317     /Users/jeromeblin/self/blinjrm/detection-datas...   test
#
# [342182 rows x 10 columns]

# %%
converter.dataset.split_proportions
# Out:
#       train  val      test
# 0  0.974338  0.0  0.025662

# %%
converter.dataset.splits
# Out:
# ['train', 'test']

# %%
converter.dataset.data.loc[16305]
# Out:
#         category_id       category  supercategory  \
# bbox_id
# 0                32         pocket  garment parts
# 1                31         sleeve  garment parts
# 2                31         sleeve  garment parts
# 3                22           sock  legs and feet
# 4                22           sock  legs and feet
# 5                28         collar  garment parts
# 6                 0  shirt, blouse      upperbody
#
#                                                       bbox width height  \
# bbox_id
# 0        <detection_dataset.bbox.Bbox object at 0x1261b...   680   1024
# 1        <detection_dataset.bbox.Bbox object at 0x1261b...   680   1024
# 2        <detection_dataset.bbox.Bbox object at 0x1261b...   680   1024
# 3        <detection_dataset.bbox.Bbox object at 0x1261b...   680   1024
# 4        <detection_dataset.bbox.Bbox object at 0x16d85...   680   1024
# 5        <detection_dataset.bbox.Bbox object at 0x1261b...   680   1024
# 6        <detection_dataset.bbox.Bbox object at 0x16d85...   680   1024
#
#           area                            image_name  \
# bbox_id
# 0         3052  2f10b4d61e445fe5d0777723630a2905.jpg
# 1        12906  2f10b4d61e445fe5d0777723630a2905.jpg
# 2         5794  2f10b4d61e445fe5d0777723630a2905.jpg
# 3         3838  2f10b4d61e445fe5d0777723630a2905.jpg
# 4         9415  2f10b4d61e445fe5d0777723630a2905.jpg
# 5         1054  2f10b4d61e445fe5d0777723630a2905.jpg
# 6        78456  2f10b4d61e445fe5d0777723630a2905.jpg
#
#                                                 image_path  split
# bbox_id
# 0        /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 1        /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 2        /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 3        /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 4        /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 5        /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 6        /Users/jeromeblin/self/blinjrm/detection-datas...  train

# %%
converter.dataset.data.loc[(16305, 0)]
# Out:
# category_id                                                     32
# category                                                    pocket
# supercategory                                        garment parts
# bbox             <detection_dataset.bbox.Bbox object at 0x1261b...
# width                                                          680
# height                                                        1024
# area                                                          3052
# image_name                    2f10b4d61e445fe5d0777723630a2905.jpg
# image_path       /Users/jeromeblin/self/blinjrm/detection-datas...
# split                                                        train
# Name: (16305, 0), dtype: object

# %%
mapping = converter.dataset.categories.copy()
mapping['new_category'] = ""
mapping['new_category_id'] = ""

# Clothing
mapping.loc[mapping.category_id.isin(range(13)), 'new_category'] = 'clothing'
mapping.loc[mapping.category_id.isin(range(13)), 'new_category_id'] = 0

# Accessories
mapping.loc[mapping.category_id.isin(range(13, 27)), 'new_category'] = 'accessories'
mapping.loc[mapping.category_id.isin(range(13, 27)), 'new_category_id'] = 2

# Shoes
mapping.loc[mapping.category_id == 23, 'new_category'] = "shoes"
mapping.loc[mapping.category_id == 23, 'new_category_id'] = 1

# Other - to be dropped
mapping.loc[mapping.category_id.isin(range(27, 46)), 'new_category'] = 'details'
mapping.loc[mapping.category_id.isin(range(27, 46)), 'new_category_id'] = -1

mapping = mapping[mapping.loc[:, 'new_category_id'] >= 0]

# %%
converter.transform(category_mapping=mapping, splits=[0.8, 0.1, 0.1], n_images=1000)
converter.dataset.data
# Out:
#                  category_id     category   supercategory  \
# image_id bbox_id
# 25836    303666            0     clothing       lowerbody
#          303667            1        shoes   legs and feet
#          303668            2  accessories  arms and hands
#          303672            0     clothing       upperbody
#          303675            0     clothing       upperbody
# ...                      ...          ...             ...
# 35191    215688            1        shoes   legs and feet
# 14154    112546            0     clothing       upperbody
#          112548            0     clothing       lowerbody
#          112549            1        shoes   legs and feet
#          112550            1        shoes   legs and feet
#
#                                                                bbox width  \
# image_id bbox_id
# 25836    303666   <detection_dataset.bbox.Bbox object at 0x13bea...   682
#          303667   <detection_dataset.bbox.Bbox object at 0x13bea...   682
#          303668   <detection_dataset.bbox.Bbox object at 0x13bea...   682
#          303672   <detection_dataset.bbox.Bbox object at 0x13bea...   682
#          303675   <detection_dataset.bbox.Bbox object at 0x13bea...   682
# ...                                                             ...   ...
# 35191    215688   <detection_dataset.bbox.Bbox object at 0x1284a...   768
# 14154    112546   <detection_dataset.bbox.Bbox object at 0x13a8e...   682
#          112548   <detection_dataset.bbox.Bbox object at 0x13a8e...   682
#          112549   <detection_dataset.bbox.Bbox object at 0x13a8e...   682
#          112550   <detection_dataset.bbox.Bbox object at 0x13a8e...   682
#
#                  height    area                            image_name  \
# image_id bbox_id
# 25836    303666    1024  136759  17a3f31bfb9e4a3214ac71d3b763af18.jpg
#          303667    1024   22804  17a3f31bfb9e4a3214ac71d3b763af18.jpg
#          303668    1024     881  17a3f31bfb9e4a3214ac71d3b763af18.jpg
#          303672    1024  158399  17a3f31bfb9e4a3214ac71d3b763af18.jpg
#          303675    1024   21912  17a3f31bfb9e4a3214ac71d3b763af18.jpg
# ...                 ...     ...                                   ...
# 35191    215688    1024    3228  1e485e96b96af3fdb7f50a0c8c9e30b0.jpg
# 14154    112546    1024    3684  67dbc3d84804b6e66ce1b8e939651eb0.jpg
#          112548    1024   36521  67dbc3d84804b6e66ce1b8e939651eb0.jpg
#          112549    1024    1209  67dbc3d84804b6e66ce1b8e939651eb0.jpg
#          112550    1024     408  67dbc3d84804b6e66ce1b8e939651eb0.jpg
#
#                                                          image_path  split
# image_id bbox_id
# 25836    303666   /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          303667   /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          303668   /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          303672   /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          303675   /Users/jeromeblin/self/blinjrm/detection-datas...  train
# ...                                                             ...    ...
# 35191    215688   /Users/jeromeblin/self/blinjrm/detection-datas...   test
# 14154    112546   /Users/jeromeblin/self/blinjrm/detection-datas...   test
#          112548   /Users/jeromeblin/self/blinjrm/detection-datas...   test
#          112549   /Users/jeromeblin/self/blinjrm/detection-datas...   test
#          112550   /Users/jeromeblin/self/blinjrm/detection-datas...   test
#
# [3554 rows x 10 columns]

# %%
write_config = {
    'dataset_format': 'yolo',
    'name': 'fashionpedia_yolo',
    'path': '/Users/jeromeblin/self/blinjrm/detection-dataset/data/',
    'destinations': ['wandb'],
}

converter.write(**write_config)
# Out:
# wandb: Currently logged in as: blinjrm. Use `wandb login --relogin` to force relogin
# wandb version 0.12.18 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/Users/jeromeblin/self/blinjrm/detection-dataset/notebooks/wandb/run-20220611_153935-y8b5nehd</code>
# Resuming run <strong><a href="https://wandb.ai/blinjrm/detection-dataset/runs/y8b5nehd" target="_blank">dataset_upload</a></strong> to <a href="https://wandb.ai/blinjrm/detection-dataset" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Adding directory to artifact (/tmp/fashionpedia_yolo)... Done. 0.6s

# %%
# import wandb
# import inspect

# inspect.signature(wandb.init)
