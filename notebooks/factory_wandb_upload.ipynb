# %%
from detection_dataset import Converter

# %%
read_config = {
    'dataset_format': 'coco',
    'path': '/Users/jeromeblin/self/blinjrm/detection-dataset/data/raw',
    'splits': {
        'train': ('train.json', 'train'),
        'test': ('test.json', 'test'),
    },
    'other': 'argument',
}

converter = Converter()
converter.read(**read_config)
converter.dataset.data.head(1)
# Out:
#                  category_id category  supercategory  \
# image_id bbox_id
# 16305    0                32   pocket  garment parts
#
#                                                                bbox width  \
# image_id bbox_id
# 16305    0        <detection_dataset.bbox.Bbox object at 0x168e1...   680
#
#                  height  area                            image_name  \
# image_id bbox_id
# 16305    0         1024  3052  2f10b4d61e445fe5d0777723630a2905.jpg
#
#                                                          image_path  split
# image_id bbox_id
# 16305    0        /Users/jeromeblin/self/blinjrm/detection-datas...  train

# %%
converter.dataset.data
# Out:
#                  category_id category  supercategory  \
# image_id bbox_id
# 16305    0                32   pocket  garment parts
#          1                31   sleeve  garment parts
#          2                31   sleeve  garment parts
#          3                22     sock  legs and feet
#          4                22     sock  legs and feet
# ...                      ...      ...            ...
# 13599    9313              8    skirt      lowerbody
#          9314             23     shoe  legs and feet
#          9315             23     shoe  legs and feet
#          9316             31   sleeve  garment parts
#          9317             31   sleeve  garment parts
#
#                                                                bbox width  \
# image_id bbox_id
# 16305    0        <detection_dataset.bbox.Bbox object at 0x168e1...   680
#          1        <detection_dataset.bbox.Bbox object at 0x168e1...   680
#          2        <detection_dataset.bbox.Bbox object at 0x168e1...   680
#          3        <detection_dataset.bbox.Bbox object at 0x168e1...   680
#          4        <detection_dataset.bbox.Bbox object at 0x168e1...   680
# ...                                                             ...   ...
# 13599    9313     <detection_dataset.bbox.Bbox object at 0x13b0e...   904
#          9314     <detection_dataset.bbox.Bbox object at 0x13b0e...   904
#          9315     <detection_dataset.bbox.Bbox object at 0x13b0e...   904
#          9316     <detection_dataset.bbox.Bbox object at 0x13b0e...   904
#          9317     <detection_dataset.bbox.Bbox object at 0x13b0e...   904
#
#                  height   area                            image_name  \
# image_id bbox_id
# 16305    0         1024   3052  2f10b4d61e445fe5d0777723630a2905.jpg
#          1         1024  12906  2f10b4d61e445fe5d0777723630a2905.jpg
#          2         1024   5794  2f10b4d61e445fe5d0777723630a2905.jpg
#          3         1024   3838  2f10b4d61e445fe5d0777723630a2905.jpg
#          4         1024   9415  2f10b4d61e445fe5d0777723630a2905.jpg
# ...                 ...    ...                                   ...
# 13599    9313      1024  62602  d456b51deebc83e01cfef985d05e063e.jpg
#          9314      1024   1531  d456b51deebc83e01cfef985d05e063e.jpg
#          9315      1024    248  d456b51deebc83e01cfef985d05e063e.jpg
#          9316      1024  10809  d456b51deebc83e01cfef985d05e063e.jpg
#          9317      1024  11092  d456b51deebc83e01cfef985d05e063e.jpg
#
#                                                          image_path  split
# image_id bbox_id
# 16305    0        /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          1        /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          2        /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          3        /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          4        /Users/jeromeblin/self/blinjrm/detection-datas...  train
# ...                                                             ...    ...
# 13599    9313     /Users/jeromeblin/self/blinjrm/detection-datas...   test
#          9314     /Users/jeromeblin/self/blinjrm/detection-datas...   test
#          9315     /Users/jeromeblin/self/blinjrm/detection-datas...   test
#          9316     /Users/jeromeblin/self/blinjrm/detection-datas...   test
#          9317     /Users/jeromeblin/self/blinjrm/detection-datas...   test
#
# [342182 rows x 10 columns]

# %%
converter.dataset.split_proportions
# Out:
#       train  val      test
# 0  0.974338  0.0  0.025662

# %%
converter.dataset.splits
# Out:
# ['train', 'test']

# %%
converter.dataset.data.loc[16305]
# Out:
#         category_id       category  supercategory  \
# bbox_id
# 0                32         pocket  garment parts
# 1                31         sleeve  garment parts
# 2                31         sleeve  garment parts
# 3                22           sock  legs and feet
# 4                22           sock  legs and feet
# 5                28         collar  garment parts
# 6                 0  shirt, blouse      upperbody
#
#                                                       bbox width height  \
# bbox_id
# 0        <detection_dataset.bbox.Bbox object at 0x168e1...   680   1024
# 1        <detection_dataset.bbox.Bbox object at 0x168e1...   680   1024
# 2        <detection_dataset.bbox.Bbox object at 0x168e1...   680   1024
# 3        <detection_dataset.bbox.Bbox object at 0x168e1...   680   1024
# 4        <detection_dataset.bbox.Bbox object at 0x168e1...   680   1024
# 5        <detection_dataset.bbox.Bbox object at 0x168e1...   680   1024
# 6        <detection_dataset.bbox.Bbox object at 0x168e1...   680   1024
#
#           area                            image_name  \
# bbox_id
# 0         3052  2f10b4d61e445fe5d0777723630a2905.jpg
# 1        12906  2f10b4d61e445fe5d0777723630a2905.jpg
# 2         5794  2f10b4d61e445fe5d0777723630a2905.jpg
# 3         3838  2f10b4d61e445fe5d0777723630a2905.jpg
# 4         9415  2f10b4d61e445fe5d0777723630a2905.jpg
# 5         1054  2f10b4d61e445fe5d0777723630a2905.jpg
# 6        78456  2f10b4d61e445fe5d0777723630a2905.jpg
#
#                                                 image_path  split
# bbox_id
# 0        /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 1        /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 2        /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 3        /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 4        /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 5        /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 6        /Users/jeromeblin/self/blinjrm/detection-datas...  train

# %%
converter.dataset.data.loc[(16305, 0)]
# Out:
# category_id                                                     32
# category                                                    pocket
# supercategory                                        garment parts
# bbox             <detection_dataset.bbox.Bbox object at 0x168e1...
# width                                                          680
# height                                                        1024
# area                                                          3052
# image_name                    2f10b4d61e445fe5d0777723630a2905.jpg
# image_path       /Users/jeromeblin/self/blinjrm/detection-datas...
# split                                                        train
# Name: (16305, 0), dtype: object

# %%
mapping = converter.dataset.categories.copy()
mapping['new_category'] = ""
mapping['new_category_id'] = ""

# Clothing
mapping.loc[mapping.category_id.isin(range(13)), 'new_category'] = 'clothing'
mapping.loc[mapping.category_id.isin(range(13)), 'new_category_id'] = 0

# Accessories
mapping.loc[mapping.category_id.isin(range(13, 27)), 'new_category'] = 'accessories'
mapping.loc[mapping.category_id.isin(range(13, 27)), 'new_category_id'] = 2

# Shoes
mapping.loc[mapping.category_id == 23, 'new_category'] = "shoes"
mapping.loc[mapping.category_id == 23, 'new_category_id'] = 1

# Other - to be dropped
mapping.loc[mapping.category_id.isin(range(27, 46)), 'new_category'] = 'details'
mapping.loc[mapping.category_id.isin(range(27, 46)), 'new_category_id'] = -1

mapping = mapping[mapping.loc[:, 'new_category_id'] >= 0]

# %%
converter.transform(category_mapping=mapping, splits=[0.9, 0.05, 0.05], n_images=10000)
converter.dataset.data
# Out:
#                  category_id     category  supercategory  \
# image_id bbox_id
# 10463    35073             0     clothing      wholebody
#          35074             1        shoes  legs and feet
#          35075             1        shoes  legs and feet
# 46760    60721             2  accessories           head
#          60727             0     clothing      lowerbody
# ...                      ...          ...            ...
# 21613    276726            0     clothing      upperbody
# 24270    294622            0     clothing      wholebody
#          294624            2  accessories          waist
#          294627            1        shoes  legs and feet
# 49259    176308            0     clothing      upperbody
#
#                                                                bbox width  \
# image_id bbox_id
# 10463    35073    <detection_dataset.bbox.Bbox object at 0x1535d...   724
#          35074    <detection_dataset.bbox.Bbox object at 0x1535d...   724
#          35075    <detection_dataset.bbox.Bbox object at 0x1535d...   724
# 46760    60721    <detection_dataset.bbox.Bbox object at 0x123a1...   682
#          60727    <detection_dataset.bbox.Bbox object at 0x123a1...   682
# ...                                                             ...   ...
# 21613    276726   <detection_dataset.bbox.Bbox object at 0x12efd...  1024
# 24270    294622   <detection_dataset.bbox.Bbox object at 0x1311b...   682
#          294624   <detection_dataset.bbox.Bbox object at 0x1311b...   682
#          294627   <detection_dataset.bbox.Bbox object at 0x1311b...   682
# 49259    176308   <detection_dataset.bbox.Bbox object at 0x15353...   656
#
#                  height    area                            image_name  \
# image_id bbox_id
# 10463    35073     1024   93445  4de27a62158b537a814e517e2c4fa92a.jpg
#          35074     1024    2839  4de27a62158b537a814e517e2c4fa92a.jpg
#          35075     1024    2755  4de27a62158b537a814e517e2c4fa92a.jpg
# 46760    60721     1024   16525  cf67e399b64ec9e7046cb7772f6ac26d.jpg
#          60727     1024   71808  cf67e399b64ec9e7046cb7772f6ac26d.jpg
# ...                 ...     ...                                   ...
# 21613    276726     682   96725  0ea47fe627541a70185bef9988ff5624.jpg
# 24270    294622    1024  144148  ccd9871555eac6eff8ebec53597eef9f.jpg
#          294624    1024    2352  ccd9871555eac6eff8ebec53597eef9f.jpg
#          294627    1024     949  ccd9871555eac6eff8ebec53597eef9f.jpg
# 49259    176308    1024  247192  2c7016357d3afdfa24c22145d218e4df.jpg
#
#                                                          image_path  split
# image_id bbox_id
# 10463    35073    /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          35074    /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          35075    /Users/jeromeblin/self/blinjrm/detection-datas...  train
# 46760    60721    /Users/jeromeblin/self/blinjrm/detection-datas...  train
#          60727    /Users/jeromeblin/self/blinjrm/detection-datas...  train
# ...                                                             ...    ...
# 21613    276726   /Users/jeromeblin/self/blinjrm/detection-datas...   test
# 24270    294622   /Users/jeromeblin/self/blinjrm/detection-datas...   test
#          294624   /Users/jeromeblin/self/blinjrm/detection-datas...   test
#          294627   /Users/jeromeblin/self/blinjrm/detection-datas...   test
# 49259    176308   /Users/jeromeblin/self/blinjrm/detection-datas...   test
#
# [36111 rows x 10 columns]

# %%
write_config = {
    'dataset_format': 'mmdet',
    'name': 'fashionpedia_mmdet',
    'path': '/Users/jeromeblin/self/blinjrm/detection-dataset/data/',
    'destinations': ['wandb'],
}

converter.write(**write_config)
# Out:
# wandb: Currently logged in as: blinjrm. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.18
# Run data is saved locally in <code>/Users/jeromeblin/self/blinjrm/detection-dataset/notebooks/wandb/run-20220612_184417-2vnkn1hj</code>
# Syncing run <strong><a href="https://wandb.ai/blinjrm/detection-dataset/runs/2vnkn1hj" target="_blank">northern-flower-13</a></strong> to <a href="https://wandb.ai/blinjrm/detection-dataset" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Adding directory to artifact (/tmp/fashionpedia_mmdet)... Done. 8.2s
